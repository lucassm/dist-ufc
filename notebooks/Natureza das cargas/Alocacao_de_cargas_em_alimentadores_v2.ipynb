# %% [markdown]
# # Natureza das Cargas - Distribuição de Engenharia Elétrica

# %% [markdown]
# ## Atividade Computacional 1 - Parte 2

# %%
import pandas as pd
import numpy as np
from IPython.display import Image

pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 8)
pd.set_option('display.max_rows', 8)

# %matplotlib inline

# %%
# %cd /home/lucas/Dropbox/Disciplinas\ UFC/Distribuição/Repositorio/notebooks/Natureza\ das\ cargas/
# Out:
# /home/lucas/Dropbox/Disciplinas UFC/Distribuição/Repositorio/notebooks/Natureza das cargas

# %% [markdown]
# ## Conjunto de dados a ser analisado

# %%
data = pd.read_excel('load_data.xlsx')

# %%
data
# Out:
#                          Load 0       Load 1       Load 2       Load 3  \
# 2018-03-01 00:00:00    0.000000     0.000000     0.000000   804.242858
# 2018-03-01 01:00:00    0.000000   307.835440   340.032575   471.779518
# 2018-03-01 02:00:00    0.000000   521.211206   481.538302   510.519216
# 2018-03-01 03:00:00    0.000000  1903.931464  1192.758170   721.718539
# ...                         ...          ...          ...          ...
# 2018-05-31 20:00:00  277.140013  2658.073582  2117.876064  1803.437938
# 2018-05-31 21:00:00  248.034263  2415.895225  1303.452500  1435.606196
# 2018-05-31 22:00:00  223.822663  1572.487371   630.230642   816.504514
# 2018-05-31 23:00:00  161.250733  1240.067543   184.812757   858.774417
#
#                         ...          Load 296     Load 297     Load 298  \
# 2018-03-01 00:00:00     ...        153.491622   298.782894   124.593434
# 2018-03-01 01:00:00     ...        801.789532  1027.237477     0.000000
# ...

# %% [markdown]
# ## Exemplo dos dados de demanda em uma das cargas

# %%
data['Load 32'].plot(figsize=(25, 5), grid=True)

# %% [markdown]
# ## Demanda diversificada do sistema

# %%
data.sum(axis=1).plot(figsize=(25, 5), grid=True)

# %% [markdown]
# ## Procedimento de Análise
#
# Com base no conjunto de dados de demanda horária disponibilizado no arquivo .xlsx, considere um sistema de distribuição em média tensão.
#
# Considere que os dados de carga em cada uma das planilhas represente consumidores conectados à transformadores da seguinte forma:
#
# T1: Load 0   - Load 23 - Potência nominal: 112,5 kVA
#
# T2: Load 24  - Load 50 - Potência nominal: 112,5 kVA
#
# T3: Load 51  - Load 65 - Potência nominal: 75 kVA
#
# T4: Load 66  - Load 110 - Potência nominal: 150 kVA
#
# T5: Load 111 - Load 150 - Potência nominal: 225 kVA
#
# T6: Load 151 - Load 175 - Potência nominal: 150 kVA
#
# T7: Load 175 - Load 220 - Potência nominal: 300 kVA
#
# T8: Load 221 - Load 250 - Potência nominal: 112,5 kVA
#
# T9: Load 251 - Load 299 - Potência nominal: 300 kVA
#
#
# ### Para esse sistema realize a seguinte análise:
#
# 1. Verifique qual o pico de carga do sistema e informe o dia e o horário da ocorrência.
#
# 2. Para o dia de ocorrência do pico do sistema plote as curvas de demanda de cada um dos transformadores e a curva de demanda diversificada do sistemas.
#
# 3. Plote em um gráfico com os horários de ocorrência da demanda máxima de cada transformador no dia de ocorrência do pico de demanda. Comente dobre a diversidade das cargas nesse sistema.
#
# 4. Monte uma tabela com os dados de demanda máxima de cada transformador, o consumo em kWh no dia de ocorrência da demanda máxima do sistema e o consumo mensal no mês de ocorrência da demanda máxima do sistema e o número de consumidores conectados em cada transformador.
#
# 5. Realize alocação de carga nos transformadores do alimentador com base nos seguintes tipos de fatores de alocação:
#
# Tipo 1:
#
# $$
# AF_1 = \frac{Demanda~Medida~em~kVA}{Potência~Nominal~dos~transformadores~em~kVA}
# $$
#
# Tipo 2:
#
# $$
# AF_2 = \frac{Demanda~Medida~em~kVA}{Consumo~Diário~em~kWh}
# $$
#
# Tipo 2:
#
# $$
# AF_2 = \frac{Demanda~Medida~em~kVA}{Consumo~Mensal~em~kWh}
# $$
#
# Com base nos valores encontrados, realize uma comparação para cada um dos transformades em relação ao caso base, plotando gráficos conforme mostrado abaixo. Analise qual método apresentou melhor resultado.
#
#
# Observações: Sempre que necessário, considere o fator de potência do sistema como 0,9 indutivo.

# %%
Image('grafico_1.png', width=600)

# %% [markdown]
# # Informações para entrega do trabalho:
#
# Enviar código dos procedimentos pelo link:
#
# https://www.dropbox.com/l/AACvr2OkfAFvS5TPhfXOujQqZB-yG2tDUXc
#
# Prazo final para envio dos arquivos: 11/04/19
#
# Data de apresentação dos resultados: 16/04/19
